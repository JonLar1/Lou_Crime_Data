# %% [markdown]
# #### Louisville Crime Data

# %%
# Import packages
import pandas as pd

# %%
# Read and create a dataframe
df = pd.[readcsv: ... ]

# %%
# Check dtypes, head, shape, info

# %%
# Combine data / csv

# %%
# Clean csv
