# %% [markdown]
# #### Louisville Crime Data

# %%
# Import packages
import pandas as pd

# %%
# Read and create a dataframe
df_2024 = pd.read_csv('/Users/jonmarklarson/Projects/lou_crime_report/data/Crime_Data_2024.csv')

# %%
# Check head
df_2024.head()
# Out:
#   incident_number          date_reported          date_occurred  badge_id  \
# 0    LMPD25144947   12/5/2025 5:28:00 PM  11/16/2024 5:00:00 AM    8701.0
# 1    LMPD25140113  11/24/2025 4:22:00 AM    7/9/2024 4:00:00 AM    8631.0
# 2    LMPD25139843  11/23/2025 2:37:00 PM  11/15/2024 9:00:00 PM    8560.0
# 3    LMPD25138669  11/20/2025 8:54:00 PM    1/1/2024 5:01:00 AM    8646.0
# 4    LMPD25138625  11/20/2025 7:29:00 PM  10/29/2024 4:00:00 PM    8544.0
#
#    offense_classification                                  offense_code_name  \
# 0  29 FRAUD IMPERSONATION  THEFT OF IDENTITY OF ANOTHER WITHOUT CONSENT 5...
# 1  29 FRAUD IMPERSONATION  THEFT OF IDENTITY OF ANOTHER WITHOUT CONSENT 5...
# 2           14 AUTO THEFT  TBUT OR DISP AUTO $1,000 < $10,000 514.030 241...
# 3  29 FRAUD IMPERSONATION  THEFT OF IDENTITY OF ANOTHER WITHOUT CONSENT 5...
# 4          23 THEFT OTHER  THEFT BY DECEPTION INCLUDING COLD CHECKS $1,00...
#
# ...

# %%
# Check info
df_2024.info
# Out:
# <bound method DataFrame.info of       incident_number           date_reported          date_occurred  \
# 0        LMPD25144947    12/5/2025 5:28:00 PM  11/16/2024 5:00:00 AM
# 1        LMPD25140113   11/24/2025 4:22:00 AM    7/9/2024 4:00:00 AM
# 2        LMPD25139843   11/23/2025 2:37:00 PM  11/15/2024 9:00:00 PM
# 3        LMPD25138669   11/20/2025 8:54:00 PM    1/1/2024 5:01:00 AM
# 4        LMPD25138625   11/20/2025 7:29:00 PM  10/29/2024 4:00:00 PM
# ...               ...                     ...                    ...
# 70763    LMPD23107772    11/5/2023 7:35:00 PM  3/30/2024 12:00:00 AM
# 70764    LMPD23106029   11/1/2023 12:27:00 PM  1/10/2024 10:15:00 PM
# 70765    LMPD23120768    11/1/2023 4:00:00 AM   2/15/2024 6:04:00 PM
# 70766    LMPD23104184   10/27/2023 1:57:00 PM  1/10/2024 10:40:00 PM
# 70767    LMPD23104309  10/26/2023 10:00:00 PM   4/11/2024 2:49:00 PM
#
#        badge_id  offense_classification  \
# 0        8701.0  29 FRAUD IMPERSONATION
# ...

# %%
# Check shape
df_2024.shape
# Out:
# (70768, 16)

# %%
# Check basic stats
df_2024.describe
# Out:
# <bound method NDFrame.describe of       incident_number           date_reported          date_occurred  \
# 0        LMPD25144947    12/5/2025 5:28:00 PM  11/16/2024 5:00:00 AM
# 1        LMPD25140113   11/24/2025 4:22:00 AM    7/9/2024 4:00:00 AM
# 2        LMPD25139843   11/23/2025 2:37:00 PM  11/15/2024 9:00:00 PM
# 3        LMPD25138669   11/20/2025 8:54:00 PM    1/1/2024 5:01:00 AM
# 4        LMPD25138625   11/20/2025 7:29:00 PM  10/29/2024 4:00:00 PM
# ...               ...                     ...                    ...
# 70763    LMPD23107772    11/5/2023 7:35:00 PM  3/30/2024 12:00:00 AM
# 70764    LMPD23106029   11/1/2023 12:27:00 PM  1/10/2024 10:15:00 PM
# 70765    LMPD23120768    11/1/2023 4:00:00 AM   2/15/2024 6:04:00 PM
# 70766    LMPD23104184   10/27/2023 1:57:00 PM  1/10/2024 10:40:00 PM
# 70767    LMPD23104309  10/26/2023 10:00:00 PM   4/11/2024 2:49:00 PM
#
#        badge_id  offense_classification  \
# 0        8701.0  29 FRAUD IMPERSONATION
# ...

# %%
# Explore individual columns

# %%
# Practice basic data cleaning and wrangling

# %%
# Combine data / csv

# %%
# Clean csv

# %%
# Run pivot tables and groupby
# What zip codes have the highest crimes in total occurring?
# What crimes occur in high crime areas vs. low crime areas?
